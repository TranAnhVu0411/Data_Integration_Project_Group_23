# %%
import pandas as pd
import folder_create as folder
import os

# %% [markdown]
# # Show sample data

# %% [markdown]
# ## Metacritic

# %%
# Movie Info
df_metacritic_movie = pd.read_csv(os.path.join(folder.metacritic_dir, "movieDatasetClean.csv"))
df_metacritic_movie.head()
# Out:
#            title  age_rating rating  rank    genre              director  \
# 0   Citizen Kane          15    8.4     1    Drama          Orson Welles
# 1  The Godfather          18    9.2     2    Drama  Francis Ford Coppola
# 2    Rear Window           0    8.8     3  Mystery      Alfred Hitchcock
# 3     Casablanca          15    8.9     4    Drama        Michael Curtiz
# 4        Boyhood          18    7.5     5    Drama     Richard Linklater
#
#    year            producer            actor  runtime  \
# 0  1941  RKO Radio Pictures    Joseph Cotten      119
# 1  1972  Paramount Pictures        Al Pacino      175
# 2  1954  Paramount Pictures       Frank Cady      112
# 3  1943        Warner Bros.  Humphrey Bogart      102
# 4  2014           IFC Films     Bonnie Cross      165
#
#                                          description  \
# 0  Following the death of a publishing tycoon, ne...
# 1  Francis Ford Coppola's epic features Marlon Br...
# ...

# %%
# Review Info
df_metacritic_review = pd.read_csv(os.path.join(folder.metacritic_dir, "reviewDatasetClean.csv"), 
                                   lineterminator='\n')
df_metacritic_review.head()
# Out:
#           title                 user      type  grade  \
# 0  Citizen Kane         larsenonfilm  reviewer    100
# 1  Citizen Kane    chicago-sun-times  reviewer    100
# 2  Citizen Kane  new-york-daily-news  reviewer    100
# 3  Citizen Kane            reelviews  reviewer    100
# 4  Citizen Kane               empire  reviewer    100
#
#                                               review  spoilers language
# 0                                                ...         0       en
# 1                                                ...         0       en
# 2                                                ...         0       en
# 3                                                ...         0       en
# 4                                                ...         0       en

# %% [markdown]
# ## Rotten Tomatoes

# %%
# Movie Info
df_tomato_movie = pd.read_csv(os.path.join(folder.tomato_dir, "rotten_tomatoes_movies.csv"))
df_tomato_movie.head()
# Out:
#                     rotten_tomatoes_link  \
# 0                              m/0814255
# 1                              m/0878835
# 2                                   m/10
# 3                 m/1000013-12_angry_men
# 4  m/1000079-20000_leagues_under_the_sea
#
#                                          movie_title  \
# 0  Percy Jackson & the Olympians: The Lightning T...
# 1                                        Please Give
# 2                                                 10
# 3                    12 Angry Men (Twelve Angry Men)
# 4                       20,000 Leagues Under The Sea
#
#                                           movie_info  \
# 0  Always trouble-prone, the life of teenager Per...
# 1  Kate (Catherine Keener) and her husband Alex (...
# 2  A successful, middle-aged Hollywood songwriter...
# 3  Following the closing arguments in a murder tr...
# 4  In 1866, Professor Pierre M. Aronnax (Paul Luk...
#
# ...

# %%
# Review Info
df_tomato_review = pd.read_csv(os.path.join(folder.tomato_dir,"rotten_tomatoes_critic_reviews.csv"))
df_tomato_review.head()
# Out:
#   rotten_tomatoes_link      critic_name  top_critic           publisher_name  \
# 0            m/0814255  Andrew L. Urban       False           Urban Cinefile
# 1            m/0814255    Louise Keller       False           Urban Cinefile
# 2            m/0814255              NaN       False      FILMINK (Australia)
# 3            m/0814255     Ben McEachen       False  Sunday Mail (Australia)
# 4            m/0814255      Ethan Alter        True       Hollywood Reporter
#
#   review_type review_score review_date  \
# 0       Fresh          NaN  2010-02-06
# 1       Fresh          NaN  2010-02-06
# 2       Fresh          NaN  2010-02-09
# 3       Fresh        3.5/5  2010-02-09
# 4      Rotten          NaN  2010-02-10
#
#                                       review_content
# 0  A fantasy adventure that fuses Greek mythology...
# 1  Uma Thurman as Medusa, the gorgon with a coiff...
# 2  With a top-notch cast and dazzling special eff...
# ...

# %% [markdown]
# ## MovieLen

# %%
# Movie Info
df_movielen_movie = pd.read_csv(os.path.join(folder.movielen_dir, "movies.csv"))
df_movielen_movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Rating Info
df_movielen_rating = pd.read_csv(os.path.join(folder.movielen_dir,"ratings.csv"))
df_movielen_rating.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1      296     5.0  1147880044
# 1       1      306     3.5  1147868817
# 2       1      307     5.0  1147868828
# 3       1      665     5.0  1147878820
# 4       1      899     3.5  1147868510

# %% [markdown]
# ## TMDB

# %%
# Movie Info
df_tmdb_movie = pd.read_csv(os.path.join(folder.tmdb_dir,"tmdb.csv"))
df_tmdb_movie.head()
# Out:
#    Unnamed: 0      id                        title  \
# 0           0   19404  Dilwale Dulhania Le Jayenge
# 1           1     278     The Shawshank Redemption
# 2           2     238                The Godfather
# 3           3  724089    Gabriel's Inferno Part II
# 4           4     424             Schindler's List
#
#                                             overview  popularity  \
# 0  Raj is a rich, carefree, happy-go-lucky second...      31.222
# 1  Framed in the 1940s for the double murder of h...      76.654
# 2  Spanning the years 1945 to 1955, a chronicle o...      75.306
# 3  Professor Gabriel Emerson finally learns the t...      21.501
# 4  The true story of how businessman Oskar Schind...      40.585
#
#    vote_average  vote_count release_date  \
# 0           8.7        3323   1995-10-20
# 1           8.7       20434   1994-09-23
# 2           8.7       15270   1972-03-14
# 3           8.6        1369   2020-07-31
# 4           8.6       12202   1993-11-30
#
# ...

# %% [markdown]
# # Data Info

# %%
print("Datasize")
print("Metacritic movies: "+str(len(df_metacritic_movie)))
print("Metacritic reviews: "+str(len(df_metacritic_review)))
print("Rotten Tomatoes movies: "+str(len(df_tomato_movie)))
print("Rotten Tomatoes reviews: "+str(len(df_tomato_review)))
print("MovieLen movies: "+str(len(df_movielen_movie)))
print("MovieLen ratings: "+str(len(df_movielen_rating)))
print("TMDB movies: "+str(len(df_tmdb_movie)))
# Out:
# Datasize
# Metacritic movies: 14213
# Metacritic reviews: 583727
# Rotten Tomatoes movies: 17712
# Rotten Tomatoes reviews: 1130017
# MovieLen movies: 62423
# MovieLen ratings: 25000095
# TMDB movies: 9480

# %%
print("Movie Info Columns")
print("Metacritic movies info columns: "+ str(list(df_metacritic_movie.columns)))
print("Rotten Tomatoes movies info columns: "+ str(list(df_tomato_movie.columns)))
print("MovieLen movies info columns: "+ str(list(df_movielen_movie.columns)))
print("TMDB movies info columns: "+ str(list(df_tmdb_movie.columns)))
# Out:
# Movie Info Columns
# Metacritic movies info columns: ['title', 'age_rating', 'rating', 'rank', 'genre', 'director', 'year', 'producer', 'actor', 'runtime', 'description', 'img', 'url']
# Rotten Tomatoes movies info columns: ['rotten_tomatoes_link', 'movie_title', 'movie_info', 'critics_consensus', 'content_rating', 'genres', 'directors', 'authors', 'actors', 'original_release_date', 'streaming_release_date', 'runtime', 'production_company', 'tomatometer_status', 'tomatometer_rating', 'tomatometer_count', 'audience_status', 'audience_rating', 'audience_count', 'tomatometer_top_critics_count', 'tomatometer_fresh_critics_count', 'tomatometer_rotten_critics_count']
# MovieLen movies info columns: ['movieId', 'title', 'genres']
# TMDB movies info columns: ['Unnamed: 0', 'id', 'title', 'overview', 'popularity', 'vote_average', 'vote_count', 'release_date', 'keywords', 'genres', 'cast', 'crew']

# %%
print("Movie Review And Rating Columns")
print("Metacritic movies review columns: "+ str(list(df_metacritic_review.columns)))
print("Rotten Tomatoes movies review columns: "+ str(list(df_tomato_review.columns)))
print("MovieLen movies rating columns: "+ str(list(df_movielen_rating.columns)))
# Out:
# Movie Review And Rating Columns
# Metacritic movies review columns: ['title', 'user', 'type', 'grade', 'review', 'spoilers', 'language']
# Rotten Tomatoes movies review columns: ['rotten_tomatoes_link', 'critic_name', 'top_critic', 'publisher_name', 'review_type', 'review_score', 'review_date', 'review_content']
# MovieLen movies rating columns: ['userId', 'movieId', 'rating', 'timestamp']
